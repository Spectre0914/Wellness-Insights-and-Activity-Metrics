# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

from google.colab import files, drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/Capstone/Data Used/hourlySteps_merged.csv')
df.head(10)
# Out:
#            Id           ActivityHour  StepTotal
# 0  1503960366  4/12/2016 12:00:00 AM        373
# 1  1503960366   4/12/2016 1:00:00 AM        160
# 2  1503960366   4/12/2016 2:00:00 AM        151
# 3  1503960366   4/12/2016 3:00:00 AM          0
# 4  1503960366   4/12/2016 4:00:00 AM          0
# 5  1503960366   4/12/2016 5:00:00 AM          0
# 6  1503960366   4/12/2016 6:00:00 AM          0
# 7  1503960366   4/12/2016 7:00:00 AM          0
# 8  1503960366   4/12/2016 8:00:00 AM        250
# 9  1503960366   4/12/2016 9:00:00 AM       1864

# %%
df.shape
# Out:
# (22099, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22099 entries, 0 to 22098
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Id            22099 non-null  int64
#  1   ActivityHour  22099 non-null  object
#  2   StepTotal     22099 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 518.1+ KB

# %%
df.isnull().sum()
# Out:
# Id              0
# ActivityHour    0
# StepTotal       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
#Converting the column to datetime according the SQL Standard
df['ActivityHour'] = pd.to_datetime(df['ActivityHour'], format='%m/%d/%Y %I:%M:%S %p')
print(df.dtypes)
# Out:
# Id                       int64
# ActivityHour    datetime64[ns]
# StepTotal                int64
# dtype: object

# %%
df.Id.nunique()
# Out:
# 33

# %%
df.head()
# Out:
#            Id        ActivityHour  StepTotal
# 0  1503960366 2016-04-12 00:00:00        373
# 1  1503960366 2016-04-12 01:00:00        160
# 2  1503960366 2016-04-12 02:00:00        151
# 3  1503960366 2016-04-12 03:00:00          0
# 4  1503960366 2016-04-12 04:00:00          0

# %%
df.to_csv('HSteps_M.csv', index = False)

# %%
files.download('HSteps_M.csv')
