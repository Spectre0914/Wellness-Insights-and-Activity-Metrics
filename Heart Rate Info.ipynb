# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

from google.colab import files, drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/Capstone/Data Used/heartrate_seconds_merged.csv')
df.head(10)
# Out:
#            Id                  Time  Value
# 0  2022484408  4/12/2016 7:21:00 AM     97
# 1  2022484408  4/12/2016 7:21:05 AM    102
# 2  2022484408  4/12/2016 7:21:10 AM    105
# 3  2022484408  4/12/2016 7:21:20 AM    103
# 4  2022484408  4/12/2016 7:21:25 AM    101
# 5  2022484408  4/12/2016 7:22:05 AM     95
# 6  2022484408  4/12/2016 7:22:10 AM     91
# 7  2022484408  4/12/2016 7:22:15 AM     93
# 8  2022484408  4/12/2016 7:22:20 AM     94
# 9  2022484408  4/12/2016 7:22:25 AM     93

# %%
df.shape
# Out:
# (2483658, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2483658 entries, 0 to 2483657
# Data columns (total 3 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   Id      int64
#  1   Time    object
#  2   Value   int64
# dtypes: int64(2), object(1)
# memory usage: 56.8+ MB

# %%
df.isnull().sum()
# Out:
# Id       0
# Time     0
# Value    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
#Converting the column to datetime according the SQL Standard
df['Time'] = pd.to_datetime(df['Time'], format='%m/%d/%Y %I:%M:%S %p')
df.dtypes
# Out:
# Id                int64
# Time     datetime64[ns]
# Value             int64
# dtype: object

# %%
df.insert(0, 'RateID', range(1, len(df) + 1))

# %%
df.Id.nunique()
# Out:
# 14

# %%
df.head()
# Out:
#    RateID          Id                Time  Value
# 0       1  2022484408 2016-04-12 07:21:00     97
# 1       2  2022484408 2016-04-12 07:21:05    102
# 2       3  2022484408 2016-04-12 07:21:10    105
# 3       4  2022484408 2016-04-12 07:21:20    103
# 4       5  2022484408 2016-04-12 07:21:25    101

# %%
df.to_csv('Heart Rate Info.csv', index = False)

# %%
files.download('Heart Rate Info.csv')
