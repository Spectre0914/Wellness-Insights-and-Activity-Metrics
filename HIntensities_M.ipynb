# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

from google.colab import files, drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/Capstone/Data Used/hourlyIntensities_merged.csv')
df.head(10)
# Out:
#            Id           ActivityHour  TotalIntensity  AverageIntensity
# 0  1503960366  4/12/2016 12:00:00 AM              20          0.333333
# 1  1503960366   4/12/2016 1:00:00 AM               8          0.133333
# 2  1503960366   4/12/2016 2:00:00 AM               7          0.116667
# 3  1503960366   4/12/2016 3:00:00 AM               0          0.000000
# 4  1503960366   4/12/2016 4:00:00 AM               0          0.000000
# 5  1503960366   4/12/2016 5:00:00 AM               0          0.000000
# 6  1503960366   4/12/2016 6:00:00 AM               0          0.000000
# 7  1503960366   4/12/2016 7:00:00 AM               0          0.000000
# 8  1503960366   4/12/2016 8:00:00 AM              13          0.216667
# 9  1503960366   4/12/2016 9:00:00 AM              30          0.500000

# %%
df.shape
# Out:
# (22099, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22099 entries, 0 to 22098
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Id                22099 non-null  int64
#  1   ActivityHour      22099 non-null  object
#  2   TotalIntensity    22099 non-null  int64
#  3   AverageIntensity  22099 non-null  float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 690.7+ KB

# %%
df.isnull().sum()
# Out:
# Id                  0
# ActivityHour        0
# TotalIntensity      0
# AverageIntensity    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
#Converting the column to datetime according the SQL Standard
df['ActivityHour'] = pd.to_datetime(df['ActivityHour'], format='%m/%d/%Y %I:%M:%S %p')
print(df.dtypes)
# Out:
# Id                           int64
# ActivityHour        datetime64[ns]
# TotalIntensity               int64
# AverageIntensity           float64
# dtype: object

# %%
df.Id.nunique()
# Out:
# 33

# %%
df.head()
# Out:
#            Id        ActivityHour  TotalIntensity  AverageIntensity
# 0  1503960366 2016-04-12 00:00:00              20          0.333333
# 1  1503960366 2016-04-12 01:00:00               8          0.133333
# 2  1503960366 2016-04-12 02:00:00               7          0.116667
# 3  1503960366 2016-04-12 03:00:00               0          0.000000
# 4  1503960366 2016-04-12 04:00:00               0          0.000000

# %%
df.to_csv('HIntensities_M.csv', index = False)

# %%
files.download('HIntensities_M.csv')
