# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

from google.colab import files, drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/Capstone/Data Used/sleepDay_merged.csv')
df.head(10)
# Out:
#            Id               SleepDay  TotalSleepRecords  TotalMinutesAsleep  \
# 0  1503960366  4/12/2016 12:00:00 AM                  1                 327
# 1  1503960366  4/13/2016 12:00:00 AM                  2                 384
# 2  1503960366  4/15/2016 12:00:00 AM                  1                 412
# 3  1503960366  4/16/2016 12:00:00 AM                  2                 340
# 4  1503960366  4/17/2016 12:00:00 AM                  1                 700
# 5  1503960366  4/19/2016 12:00:00 AM                  1                 304
# 6  1503960366  4/20/2016 12:00:00 AM                  1                 360
# 7  1503960366  4/21/2016 12:00:00 AM                  1                 325
# 8  1503960366  4/23/2016 12:00:00 AM                  1                 361
# 9  1503960366  4/24/2016 12:00:00 AM                  1                 430
#
#    TotalTimeInBed
# 0             346
# 1             407
# 2             442
# 3             367
# 4             712
# ...

# %%
df.shape
# Out:
# (413, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 413 entries, 0 to 412
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Id                  413 non-null    int64
#  1   SleepDay            413 non-null    object
#  2   TotalSleepRecords   413 non-null    int64
#  3   TotalMinutesAsleep  413 non-null    int64
#  4   TotalTimeInBed      413 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 16.3+ KB

# %%
df.isnull().sum()
# Out:
# Id                    0
# SleepDay              0
# TotalSleepRecords     0
# TotalMinutesAsleep    0
# TotalTimeInBed        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 3

# %%
#Converting the column to datetime according the SQL Standard
df['SleepDay'] = pd.to_datetime(df['SleepDay'], format='%m/%d/%Y %I:%M:%S %p')
df.dtypes
# Out:
# Id                             int64
# SleepDay              datetime64[ns]
# TotalSleepRecords              int64
# TotalMinutesAsleep             int64
# TotalTimeInBed                 int64
# dtype: object

# %%
df.insert(0, 'SleepID', range(1, len(df) + 1))

# %%
df.Id.nunique()
# Out:
# 24

# %%
df.head()
# Out:
#    SleepID          Id   SleepDay  TotalSleepRecords  TotalMinutesAsleep  \
# 0        1  1503960366 2016-04-12                  1                 327
# 1        2  1503960366 2016-04-13                  2                 384
# 2        3  1503960366 2016-04-15                  1                 412
# 3        4  1503960366 2016-04-16                  2                 340
# 4        5  1503960366 2016-04-17                  1                 700
#
#    TotalTimeInBed
# 0             346
# 1             407
# 2             442
# 3             367
# 4             712

# %%
df.to_csv('Sleep Info.csv', index = False)

# %%
files.download('Sleep Info.csv')
