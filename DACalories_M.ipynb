# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

from google.colab import files, drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/Capstone/Data Used/dailyCalories_merged.csv')
df.head(10)
# Out:
#            Id ActivityDay  Calories
# 0  1503960366   4/12/2016      1985
# 1  1503960366   4/13/2016      1797
# 2  1503960366   4/14/2016      1776
# 3  1503960366   4/15/2016      1745
# 4  1503960366   4/16/2016      1863
# 5  1503960366   4/17/2016      1728
# 6  1503960366   4/18/2016      1921
# 7  1503960366   4/19/2016      2035
# 8  1503960366   4/20/2016      1786
# 9  1503960366   4/21/2016      1775

# %%
df.shape
# Out:
# (940, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 940 entries, 0 to 939
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Id           940 non-null    int64
#  1   ActivityDay  940 non-null    object
#  2   Calories     940 non-null    int64
# dtypes: int64(2), object(1)
# memory usage: 22.2+ KB

# %%
df.isnull().sum()
# Out:
# Id             0
# ActivityDay    0
# Calories       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['ActivityDay'] = pd.to_datetime(df['ActivityDay'])
df.dtypes
# Out:
# Id                      int64
# ActivityDay    datetime64[ns]
# Calories                int64
# dtype: object

# %%
df.Id.nunique()
# Out:
# 33

# %%
df.head()
# Out:
#            Id ActivityDay  Calories
# 0  1503960366  2016-04-12      1985
# 1  1503960366  2016-04-13      1797
# 2  1503960366  2016-04-14      1776
# 3  1503960366  2016-04-15      1745
# 4  1503960366  2016-04-16      1863

# %%
df.to_csv('DACalories_M.csv', index = False)

# %%
files.download('DACalories_M.csv')
